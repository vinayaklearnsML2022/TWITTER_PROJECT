# %%
# pip install transformers

# %%
# !pip install transformers[tf-cpu]

# %%
# pip install transformers[torch]

# %%
# pip install --upgrade pip

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis",model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
res = classifier("I want to learn ML and people are saying i'm too ole, but i can learn easily")

print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9772590398788452}]

# %%
res = classifier("Hey fool. dont look at me. Are you mad ??")


print(res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9955561757087708}]

# %%
import deep_translator
from deep_translator import GoogleTranslator
text = "ஸ்டாலின், நீங்கள் இழக்கப் போகிறீர்கள்"

res = classifier(text)
print(res)
upd_res = classifier(GoogleTranslator(source='auto').translate(text))

print(upd_res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.899028480052948}]
# [{'label': 'NEGATIVE', 'score': 0.9996339082717896}]

# %%
res = classifier("ஏய், பிரசாந்த். நான் தமிழ் கருத்துக்களை பயன்படுத்தினேன். அதுவும் நன்றாக வேலை செய்கிறது")

print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.8193510174751282}]

# %%
res = classifier("ஏய், லிங்கேஷ். உரையை வகைப்படுத்த தமிழைப் பயன்படுத்தினேன். அது நன்றாக வேலை செய்கிறது")
print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.684635579586029}]

# %%
res = classifier("अरे, लिंगेश. मैंने पाठ को वर्गीकृत करने के लिए तमिल का उपयोग किया। ये अच्छी तरह काम करता है")

print(res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.8797035813331604}]

# %%
res = classifier("ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்")

print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.8965129256248474}]

# %%
res = classifier("50 people went to nightclub to have a good night and 1 man's actions means those people are lost to their families forever #rip#orlando")

print(res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9716154336929321}]

# %%
import pandas as pd
import numpy as np
colnames = ['target', 'id', 'date','flag','user','text']
twitter_data = pd.read_csv('data/training.1600000.processed.noemoticon.csv',encoding='ISO-8859-1',names= colnames)
twitter_data['text']
# Out:
# 0          @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          is upset that he can't update his Facebook by ...
# 2          @Kenichan I dived many times for the ball. Man...
# 3            my whole body feels itchy and like its on fire
# 4          @nationwideclass no, it's not behaving at all....
#                                  ...
# 1048571             My GrandMa is making Dinenr with my Mum
# 1048572    Mid-morning snack time... A bowl of cheese noo...
# 1048573    @ShaDeLa same here  say it like from the Termi...
# 1048574               @DestinyHope92 im great thaanks  wbuu?
# 1048575                 cant wait til her date this weekend
# Name: text, Length: 1048576, dtype: object

# %%
len(twitter_data['text'])
# Out:
# 1048576

# %%
twitter_data['text'][1]
# Out:
# "is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!"

# %%
# from deep_translator import GoogleTranslator
# arr = []
# for i in range(len(twitter_data['text'])):
#     arr.append(GoogleTranslator(source='auto').translate(twitter_data['text'][i]))
# print(translated)
# twitter_data['text_mod'] = translated

# %%
# arr.tolist()[:100]

# %%
twitter_data['text'].tolist()[:1000]
# Out:
# ["@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D",
#  "is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!",
#  '@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds',
#  'my whole body feels itchy and like its on fire ',
#  "@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there. ",
#  '@Kwesidei not the whole crew ',
#  'Need a hug ',
#  "@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?",
#  "@Tatiana_K nope they didn't have it ",
#  '@twittera que me muera ? ',
#  "spring break in plain city... it's snowing ",
#  'I just re-pierced my ears ',
#  "@caregiving I couldn't bear to watch it.  And I thought the UA loss was embarrassing . . . . .",
# ...

# %%
# from deep_translator import GoogleTranslator
# to_translate = ['ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்','ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்']
# translated = GoogleTranslator(source='auto').translate(twitter_data['text'])
# print(translated)
# twitter_data['text_mod'] = translated

# %%
res = classifier(twitter_data['text'].tolist()[:1000])

# %%
len(res)
# Out:
# 1000

# %%
ypred = []
for i in range(len(res)):
    # print(f" index = {i} value= {res[i]['label']}")
    ypred.append(res[i]['label'])


print(ypred)
# Out:
# ['NEGATIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', '
# ...

# %%
res = classifier("சிவா, உங்கள் எண்ணங்கள் அனைத்தும் போற்றப்பட வேண்டும் என்று விரும்புகிறேன்")

print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.5831096172332764}]

# %%
res = classifier("siva, i wish all your thinking will cherish ")

print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9962401390075684}]

# %%
res = classifier("i'm totally upset with the things happening in our country")

print(res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9902439713478088}]

# %%
# !pip install googletrans==4.0.0rc1

# %%
 from googletrans import Translator
 translator = Translator()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from googletrans import Translator
#       2 translator = Translator()
#
# ModuleNotFoundError: No module named 'googletrans'

# %%
dir(translator)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_parse_extra_data',
#  '_pick_service_url',
#  '_translate',
#  'client',
#  'detect',
#  'raise_exception',
#  'service_urls',
#  'token_acquirer',
#  'translate']

# %%
from_lang = 'en'
to_lang = 'hi'

# %%
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
import googletrans

# print(googletrans.LANGUAGES)
from googletrans import Translator
translator = Translator()
result = translator.translate('Mitä sinä teet')

# text_to_translate = translator.translate("ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்")
text_to_translate = translator.translate("Siva, I wish all your thoughts should be admired")
print(text_to_translate.text)
# Out:
# Siva, I wish all your thoughts should be admired

# %%
# Out:
# Translated(src=ta, dest=en, text=Siva, I wish all your thoughts should be admired, pronunciation=None, extra_data="{'confiden...")

# %%
print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
import google.cloud

# %%
# Imports the Google Cloud Translation library
from google.cloud import translate


# Initialize Translation client
def translate_text(
    text: str = "YOUR_TEXT_TO_TRANSLATE", project_id: str = "YOUR_PROJECT_ID"
) -> translate.TranslationServiceClient:
    """Translating Text."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    # Translate text from English to French
    # Detail on supported types can be found here:
    # https://cloud.google.com/translate/docs/supported-formats
    response = client.translate_text(
        request={
            "parent": parent,
            "contents": [text],
            "mime_type": "text/plain",  # mime types: text/plain, text/html
            "source_language_code": "en-US",
            "target_language_code": "fr",
        }
    )

    # Display the translation for each input text provided
    for translation in response.translations:
        print(f"Translated text: {translation.translated_text}")

    return response
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Imports the Google Cloud Translation library
# ----> 2 from google.cloud import translate
#       5 # Initialize Translation client
#       6 def translate_text(
#       7     text: str = "YOUR_TEXT_TO_TRANSLATE", project_id: str = "YOUR_PROJECT_ID"
#       8 ) -> translate.TranslationServiceClient:
#
# ImportError: cannot import name 'translate' from 'google.cloud' (unknown location)

# %%
# !pip install google.cloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip install deep-translator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
#    ---------------------------------------- 42.3/42.3 kB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts deep-translator.exe and dt.exe are installed in 'C:\Users\User\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from deep_translator import GoogleTranslator
to_translate = ['ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்','ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்']
translated = GoogleTranslator(source='auto').translate(to_translate)
print(translated)
# Out:
# ---------------------------------------------------------------------------
# NotValidPayload                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 from deep_translator import GoogleTranslator
#       2 to_translate = ['ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்','ஸ்டாலின் வரப்போகிறார். விடியல் கொடுக்கப் போகிறார்']
# ----> 3 translated = GoogleTranslator(source='auto').translate(to_translate)
#       4 print(translated)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\deep_translator\google.py:57, in GoogleTranslator.translate(self, text, **kwargs)
#      51 def translate(self, text: str, **kwargs) -> str:
#      52     """
#      53     function to translate a text
#      54     @param text: desired text to translate
#      55     @return: str: translated text
#      56     """
# ---> 57     if is_input_valid(text, max_chars=5000):
#      58         text = text.strip()
# ...

# %%
dir(translated)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...
